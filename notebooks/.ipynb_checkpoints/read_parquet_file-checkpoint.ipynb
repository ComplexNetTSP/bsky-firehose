# %%
import polars as pl

# %%
df = (
    pl.read_parquet("../output.parquet")
    # Parse JSON string to struct
    .select([
    "commit_cid",
    "repo",
    "rev",
    "seq",
    "prev_cid",
    "time",
    "blob_cids",
    pl.col("ops").str.json_decode(
        pl.List(pl.Struct([
            pl.Field("action", pl.Utf8),
            pl.Field("cid", pl.Utf8),  # Now it's just a string
            pl.Field("path", pl.Utf8),
            pl.Field("record_type", pl.Utf8),
        ]))).alias("ops_parsed")
    ]).explode("ops_parsed").unnest("ops_parsed")
)

# %%
df
# Out:
# shape: (3_034, 10)
# ┌────────────┬────────────┬───────────┬───────────┬───┬───────────┬────────┬───────────┬───────────┐
# │ commit_cid ┆ repo       ┆ rev       ┆ seq       ┆ … ┆ blob_cids ┆ action ┆ cid       ┆ path      │
# │ ---        ┆ ---        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---    ┆ ---       ┆ ---       │
# │ str        ┆ str        ┆ str       ┆ i64       ┆   ┆ list[str] ┆ str    ┆ str       ┆ str       │
# ╞════════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪════════╪═══════════╪═══════════╡
# │ bafyreidu2 ┆ did:plc:zx ┆ 3mndc7qbi ┆ 305770111 ┆ … ┆ []        ┆ create ┆ bafyreigd ┆ app.bsky. │
# │ 44r2j4w52m ┆ r4sfpjyqiy ┆ mk2y      ┆ 92        ┆   ┆           ┆        ┆ 6vvlrao4i ┆ feed.post │
# │ 2khsa2ogvu ┆ dmp2c2zw7r ┆           ┆           ┆   ┆           ┆        ┆ ntytkyjgh ┆ /3mndc7qf │
# │ …          ┆ …          ┆           ┆           ┆   ┆           ┆        ┆ eep…      ┆ 2is…      │
# │ bafyreicrm ┆ did:plc:zr ┆ 3mndc7q7k ┆ 305770111 ┆ … ┆ []        ┆ create ┆ bafyreide ┆ app.bsky. │
# │ 4m46kqvwaj ┆ ur4mmsyqp3 ┆ qo2d      ┆ 93        ┆   ┆           ┆        ┆ yfb7wcue3 ┆ feed.like │
# │ vvrpxr76sf ┆ 3pqmbngyvq ┆           ┆           ┆   ┆           ┆        ┆ v4xcmt4nw ┆ /3mndc7q7 │
# │ …          ┆ …          ┆           ┆           ┆   ┆           ┆        ┆ adi…      ┆ hsw…      │
# │ bafyreihoi ┆ did:plc:iu ┆ 3mndc7pzr ┆ 305770111 ┆ … ┆ []        ┆ create ┆ bafyreid2 ┆ app.bsky. │
# │ zcctxb3v22 ┆ mgwxujk4uh ┆ 7c2o      ┆ 94        ┆   ┆           ┆        ┆ q3ike5dum ┆ feed.like │
# │ 4qfm5gba3v ┆ otra7koh5y ┆           ┆           ┆   ┆           ┆        ┆ hqkgaql2r ┆ /3mndc7pz │
# │ …          ┆ …          ┆           ┆           ┆   ┆           ┆        ┆ qga…      ┆ kek…      │
# │ bafyreibcb ┆ did:plc:qc ┆ 3mndc7pw3 ┆ 305770111 ┆ … ┆ []        ┆ create ┆ bafyreidy ┆ app.bsky. │
# │ p5weobia6a ┆ nlywqpofwa ┆ yc24      ┆ 95        ┆   ┆           ┆        ┆ 2t6f4whnq ┆ feed.repo │
# │ ybnelresik ┆ scxhecgc66 ┆           ┆           ┆   ┆           ┆        ┆ hj6zdwsb7 ┆ st/3mndc7 │
# │ …          ┆ …          ┆           ┆           ┆   ┆           ┆        ┆ dgr…      ┆ pv3…      │
# │ bafyreih2i ┆ did:plc:rv ┆ 3mndc7qa2 ┆ 305770111 ┆ … ┆ []        ┆ create ┆ bafyreidq ┆ app.bsky. │
# │ p3w2y35lw4 ┆ fgpjk7noge ┆ eu2x      ┆ 96        ┆   ┆           ┆        ┆ mj5hcupou ┆ feed.like │
# │ gtaxodztad ┆ 4odaoiudjk ┆           ┆           ┆   ┆           ┆        ┆ hd5frkzxd ┆ /3mndc7q7 │
# │ …          ┆ …          ┆           ┆           ┆   ┆           ┆        ┆ xyh…      ┆ sku…      │
# │ …          ┆ …          ┆ …         ┆ …         ┆ … ┆ …         ┆ …      ┆ …         ┆ …         │
# │ bafyreiap7 ┆ did:plc:i6 ┆ 3mndc7w5o ┆ 305770141 ┆ … ┆ []        ┆ delete ┆ null      ┆ app.bsky. │
# │ eygsvx5pml ┆ 3lep4xsvxs ┆ wi2p      ┆ 97        ┆   ┆           ┆        ┆           ┆ graph.fol │
# │ f7ju6l77nf ┆ xsh43ntwgt ┆           ┆           ┆   ┆           ┆        ┆           ┆ low/3mlwd │
# │ …          ┆ …          ┆           ┆           ┆   ┆           ┆        ┆           ┆ 3c7…      │
# │ bafyreidc3 ┆ did:plc:of ┆ 3mndc7vmv ┆ 305770141 ┆ … ┆ []        ┆ create ┆ bafyreicf ┆ app.bsky. │
# │ 3hvdwehans ┆ rec4bep73t ┆ 3522      ┆ 98        ┆   ┆           ┆        ┆ b25ms3tdn ┆ feed.post │
# │ z3pbldzkiv ┆ s4xe5kw6ti ┆           ┆           ┆   ┆           ┆        ┆ 64aqmwaup ┆ /3mndc7oa │
# │ …          ┆ …          ┆           ┆           ┆   ┆           ┆        ┆ wkc…      ┆ rwk…      │
# │ bafyreicvg ┆ did:plc:yj ┆ 3mndc7vsc ┆ 305770141 ┆ … ┆ []        ┆ create ┆ bafyreias ┆ app.bsky. │
# │ vbddoycpm6 ┆ mi6wgg2kms ┆ jj2a      ┆ 99        ┆   ┆           ┆        ┆ lhcfxi4cb ┆ feed.like │
# │ e2zf2ckalj ┆ fr3nudsdna ┆           ┆           ┆   ┆           ┆        ┆ 2eal4nb3t ┆ /3mndc7vs │
# │ …          ┆ …          ┆           ┆           ┆   ┆           ┆        ┆ gtr…      ┆ 3or…      │
# │ bafyreidzr ┆ did:plc:e4 ┆ 3mndc7v6a ┆ 305770142 ┆ … ┆ []        ┆ create ┆ bafyreife ┆ app.bsky. │
# │ detyptyts4 ┆ pzgjnlyh2u ┆ zw2j      ┆ 00        ┆   ┆           ┆        ┆ epldjofpm ┆ feed.like │
# │ 5tszs6whcr ┆ kxnhru44gi ┆           ┆           ┆   ┆           ┆        ┆ hulsrjd2v ┆ /3mndc7v5 │
# │ …          ┆ …          ┆           ┆           ┆   ┆           ┆        ┆ nci…      ┆ yao…      │
# │ bafyreieiu ┆ did:plc:vj ┆ 3mndc7vyt ┆ 305770142 ┆ … ┆ []        ┆ create ┆ bafyreihz ┆ app.bsky. │
# │ fbpi6gczg7 ┆ v23nqsyvmx ┆ sy2l      ┆ 01        ┆   ┆           ┆        ┆ 2ykoavpxc ┆ feed.repo │
# │ znz7w3cspd ┆ dmamssa2qy ┆           ┆           ┆   ┆           ┆        ┆ i2kicfyq7 ┆ st/3mndc7 │
# │ …          ┆ …          ┆           ┆           ┆   ┆           ┆        ┆ n66…      ┆ vyk…      │
# └────────────┴────────────┴───────────┴───────────┴───┴───────────┴────────┴───────────┴───────────┘
